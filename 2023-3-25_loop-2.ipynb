# %% [markdown]
# ## what did I learn from v1?
#
# Even though it was instructed to avoid it, Goldfang (still just find the name funny) made huge trades anyway. It invested ~40% in Nike because it thought it was undervalued, and hey, maybe it is / was. But it will take months or years to prove out if this kind of investing is really successful or just lucky, and by then the place will be saturated by bots that are doing something similar because it's just too easy.
#
# The basic loop I built was to look at stocks one at a time, and ignore almost all other information. I chose randomly from a list of 200 S&P 500 stocks that ChatGPT made. Maybe there's a better way to choose which stocks to look at: which ones have news associated with them, and ask Goldfang if it's worth trading on this news.
#
# I built a placeholder for feeding back open-ended data into the model, but haven't decided how to implement that. I don't think there's anything I could use as an _effective_ oracle right now. It would be sweet if I could feed those queries into a Bing Chat API or Perplexity API, have it do whatever searches it needs to do, and receive a paragraph back of text answering the question in a way that's probably correct.
#
# #### things to try
# - [ ] margin trading / short selling: https://alpaca.markets/docs/trading/margin-and-shorting/
# - [ ] trade only on newsy stocks
# - [ ] what happens if I just use ChatGPT as the oracle for now?
# - [ ] put in more macroeconomic data
# - [ ] token optimization: delete unnecessary fields, shorten numbers, etc
# - [ ] token optimization: detect when token overflow will / might happen, and remove content
# - [ ] fix broken API calls by moving to https://data.nasdaq.com/

# %% [markdown]
# ## Short selling
# read https://alpaca.markets/docs/trading/margin-and-shorting/

# %% [markdown]
# ## Get all news since last run / in last 24 hours, and examing those stocks
# using https://alpaca.markets/docs/market-data/news/

# %%
import requests
import json
with open('alpaca-keys.json') as f:
    alpaca = json.loads(f.read())
    
def get_news_summary(symbol="", limit=10):
    headers = {
        'Apca-Api-Key-Id': alpaca['key'],
        'Apca-Api-Secret-Key': alpaca['secret']
    }
    if len(symbol) > 0:
        j = requests.get(f'https://data.alpaca.markets/v1beta1/news?symbols={symbol}', headers=headers).json()
    else:
        j = requests.get(f'https://data.alpaca.markets/v1beta1/news', headers=headers).json()
    news_str = ""
    for item in j['news'][:limit]:
        news_str += f"{item['created_at']}: {item['headline']}"
        if len(item['summary'].strip()) > 0:
            news_str += ' – summary: '+item['summary'].replace('\n', ' ').strip() + '\n'
        else:
            news_str += '\n'
    return news_str
# print(get_news_summary('AAPL'))

# %%
from collections import defaultdict

def summarize_news_list(news_list, include_body=False):
    if include_body:
        raise Exception("currently not sure how to get the body without scraping it")
    news_str = ""
    for item in news_list:
        news_str += f"{item['created_at']}: {item['headline']}"
        if len(item['summary'].strip()) > 0:
            news_str += ' – summary: '+item['summary'].replace('\n', ' ').strip() + '\n'
        else:
            news_str += '\n'
    return news_str

def get_news_dict(limit=50, symbols=[]):
    headers = {
        'Apca-Api-Key-Id': alpaca['key'],
        'Apca-Api-Secret-Key': alpaca['secret']
    }
    if len(symbols) == 0:
        j = requests.get(f'https://data.alpaca.markets/v1beta1/news?limit={limit}', headers=headers).json()
    else:
        j = requests.get(f'https://data.alpaca.markets/v1beta1/news?limit={limit}&symbols={",".join(symbols)}', headers=headers).json()
    sym_to_news = defaultdict(list)
    for item in j['news']:
        for symbol in item['symbols']:
            sym_to_news[symbol].append(item)
    return sym_to_news
# news_dict = get_news_dict()

# %%
# for symbol, news_list in news_dict.items():
#     print(symbol)
#     print(summarize_news_list(news_list))
#     break

# %%
# created_dates = [item['created_at'] for news_list in news_dict.values() for item in news_list]

# %%
# sorted(created_dates)[0], sorted(created_dates)[-1]

# %% [markdown]
# So the range for these last 50 news articles is about a day. Seems good to me!

# %% [markdown]
# ## Use ChatGPT as its own oracle
# extract its previous queries and see what happens when fed back into itself with the correct system prompt.

# %%
from openai_utils import query_openai

# %%
system_oracle = '''
You are Libra Anker, a market analyst for. You work for Fantasia Goldfang, a financial advisor for higher-income working professionals. 

Every day, your Fantasia will query you for information relevant to asset allocations. Your answers, which go into the final report and 
decision-making, are always crisp, clear, concise, and factual.
'''

prompt_oracle = '''
The following is a query the ticker symbol {symbol}:
{gpt_query}

Dated: {date_str}
'''

# %%
with open('notes.json') as f:
    notes = json.loads(f.read())

# %%
def extract_query(decision):
    try:
        return decision.split('Information requests:')[1].split('Verdict')[0].strip()
    except:
        return '?'

# %%
from datetime import datetime
queries = {}
for symbol, note_list in notes.items():
    note = note_list[-1]
    # print(symbol, extract_query(note['note']))
    query = extract_query(note['note'])
    if 'news' in query:
        print('skipping query for news:', query)
        continue
    queries[symbol] = { 'symbol': symbol, 'query': query, 'date_str': note['date'] }
# Out:
# skipping query for news: Please provide the latest quarterly report for NVDA and any news on upcoming product launches.
# skipping query for news: Please check the latest news on General Mills, Inc. and any upcoming changes.
# skipping query for news: "latest news on Monster Beverage Corporation"
# skipping query for news: Search for recent news surrounding Yum! Brands, Inc. to get an idea of the future outlook for the company. Additionally, look into the company's competition and industry trends.
# skipping query for news: Search for news articles and analyst reports on Exelon Corporation's current operations, any major upcoming projects, and their expected impact on the company's stock price. Additionally, retrieve historical trends and the future outlook of the utility sector.
# skipping query for news: Search for recent news about Kimberly-Clark Corp.'s management and plans for future growth.
# skipping query for news: 1) Recent news (if available)
# 2) Dividend history of Ecolab, Inc.
# 3) Industry comparison of valuation ratios
# skipping query for news: Please provide news search results for Wabtec Inc. over the past month.
# skipping query for news: Please gather news on the reasons behind the recent decline in the stock price of PNC Financial Services Group.
# skipping query for news: Please search for recent news on Intel's restructuring plan and any updates on chip demand and supply chain issues.
# skipping query for news: 1) Search recent news about Salesforce, Inc. to determine whether there is any significant information not available in this query that may impact this investment decision.
# 2) Investigate the company's recent operating margin trend to assess whether it is consistent or declining.
# skipping query for news: Please search for recent news on Constellation Brands, Inc. and any major competitors in the industry.
# skipping query for news: Please provide a recent news update for Northrop Grumman Corp. and the sector trends for the defense industry.
# skipping query for news: Search for recent news about NetApp Inc., particularly any news on potential growth in the data storage industry.
# skipping query for news: Please search for any recent news about Honeywell International Inc. Common Stock that may have affected its stock price, and any upcoming industry or market events that could impact the company's performance.
# skipping query for news: Please search for recent news on issues with the company's supply chain and distribution channels. Please also provide information on any upcoming projects or partnerships related to their business.
# skipping query for news: Please provide news or announcements regarding any changes in the senior leadership, new strategic partnerships, or acquisitions made by Northern Trust Corporation.
# skipping query for news: 1. Latest news on Abbott Laboratories and how it could impact the company's future performance
# 2. Comparison of Abbott Laboratories' financials with its competitors
# skipping query for news: Please search for recent news and analyst reports on General Electric Company.
# skipping query for news: Please provide a news feed on DXC's recent announcements and press releases.
# skipping query for news: Search for recent news and analyst reports about Flowserve Corporation to get a better understanding of the company's current standing in the market and performance outlook.
# skipping query for news: "Becton, Dickinson and Co. stock news," "Becton, Dickinson and Co. financial ratios," "Becton, Dickinson and Co. revenue by product segment"
# skipping query for news: Search for news and analyst reports on Digital Realty Trust, Inc., and also search for the trend in the performance of data center REITs in the recent months.
# skipping query for news: Please conduct a search on the company's dividend history and any recent news that may not have been captured by the API.
# skipping query for news: Search for news on EQT's recent production and revenue trends, industry natural gas prices, and the company's major expenditures.
# skipping query for news: news articles about the company's latest developments and future plans, analyst reports and forecasts, and competitor analysis.
# skipping query for news: Find recent news articles about any changes in the company's leadership or any major partnerships or collaborations they might have announced.
# skipping query for news: Search for competitor data and news, "Loews Corporation insurance segment financials."
# skipping query for news: Please provide news and analysis on recent events that could potentially impact senior housing, medical office and skilled nursing facilities. Also, give me insights on other companies in the REIT industry that have similar market capitalization as Welltower Inc.
# skipping query for news: Please gather more information on any recent developments or news related to Oracle Corporation that may have an impact on its future stock price performance.
# skipping query for news: 1. Can you please provide more financial information about Warner Bros. Discovery, Inc. Series A Common Stock?
# 2. Can you please gather information on the potential impact of the recent news about former President Trump's potential arrest on the company's reputation and stock price?
# skipping query for news: Please keep monitoring the company's website and financial news for updates on their latest financial statements. Also, please search for any news or reports on the company's industry and competitors to get a better understanding of the potential risks and opportunities.
# skipping query for news: Please provide information on the competitors of Seelos Therapeutics and any recent news about ASIB or MDD treatments.
# skipping query for news: 1. Can you provide an analysis of the company's debt and how it might impact their financial stability?
# 2. Can you research any recent news or analyst reports that might explain the recent downward trend in the company's financial performance?
# skipping query for news: Please get the latest news on the takeover bids from Sheikh Jassim Bin Hamad Al Thani and Jim Ratcliffe and whether any new bids have been made by other investors.
# skipping query for news: Please provide any additional financial data available for ARK Fintech Innovation ETF, including the fund's performance history and any relevant news on its holdings.

# %%
len(queries)
# Out:
# 38

# %% [markdown]
# Maybe I should tell Goldfang not to query for news (at least, until I've got this hooked up to a live oracle).

# %%
import random
print(random.choice(list(queries.values())))
# Out:
# {'symbol': 'RMD', 'query': '- Market trends and forecasts for the respiratory medical equipment and software industry\n- Any significant changes in the competitive landscape for ResMed Inc., including new entrants to the industry and changes in market share\n- Potential future catalysts or disruptors for the industry or ResMed Inc. specifically', 'date_str': '2023-03-24 15:21:02.841990'}

# %%
queries
# Out:
# {'WEC': {'symbol': 'WEC',
#   'query': "1. Latest earnings call notes \n2. Competitors' sales growth figures \n3. Dividend history and payout ratio",
#   'date_str': '2023-03-24 14:59:27.472868'},
#  'PG': {'symbol': 'PG',
#   'query': "Please provide the latest updates on the company's marketing strategies and product innovations. Also, provide an overview of the competition in the consumer goods industry, with a focus on the companies that directly compete with Procter & Gamble.",
#   'date_str': '2023-03-24 15:11:19.924480'},
#  'AIG': {'symbol': 'AIG',
#   'query': "Please provide a detailed analysis of AIG's recent business performance and future growth prospects. Also, provide the latest update on the interest rate environment and inflation trends.",
#   'date_str': '2023-03-24 15:11:34.405238'},
#  'HLT': {'symbol': 'HLT',
#   'query': '1. The recent initiatives taken by the company to boost profitability.\n2. The industry and market trends with respect to hospitality companies.',
#   'date_str': '2023-03-24 15:11:49.168019'},
#  'AWK': {'symbol': 'AWK',
#   'query': "1. American Water Works Company, Inc's 5-year financial analysis. \n2. A comparison of American Water Works Company, Inc's financial ratios with those of its peers.",
#   'date_str': '2023-03-24 15:12:48.237553'},
#  'MRK': {'symbol': 'MRK',
#   'query': '"Merck & Co., Inc. share price forecast for the next year", "Recent developments in Merck & Co.\'s oncology pipeline", "Competitors\' stock prices and market share in the pharmaceutical industry"',
#   'date_str': '2023-03-24 15:13:02.061883'},
#  'HUM': {'symbol': 'HUM',
#   'query': 'Please retrieve current industry trends on health insurance companies, and the recent impacts of inflation on the healthcare industry.',
#   'date_str': '2023-03-24 15:13:57.049826'},
#  'IP': {'symbol': 'IP',
#   'query': "Please provide more information on the company's debt levels, cash flow, and dividend history.",
#   'date_str': '2023-03-24 15:14:25.210676'},
#  'MCD': {'symbol': 'MCD',
#   'query': "Please provide the company's historical P/E ratio and the company's dividend yield.",
#   'date_str': '2023-03-24 15:14:36.092082'},
#  'NKE': {'symbol': 'NKE',
#   'query': "Please provide Nike's P/E ratio compared to a relevant industry benchmark.",
#   'date_str': '2023-03-24 15:18:05.559514'},
#  'O': {'symbol': 'O',
#   'query': "Please provide information on the company's dividend yield and payout history, as well as a comparison of the company's P/E ratio to its industry peers.",
#   'date_str': '2023-03-24 15:19:09.665617'},
#  'VTRS': {'symbol': 'VTRS',
#   'query': "Please provide a breakdown of Viatris Inc.'s revenue by product type and compare it with their previous year's revenue.",
#   'date_str': '2023-03-24 15:19:23.137151'},
#  'NEE': {'symbol': 'NEE',
#   'query': "Please provide the company's revenue breakdown by energy type and an analysis of the utility industry's growth outlook for the next 3-5 years.",
#   'date_str': '2023-03-24 15:19:32.844521'},
#  'EVRG': {'symbol': 'EVRG',
#   'query': "Please provide a detailed analysis of the current competition in the electricity market and the trend of renewable energy companies' growth. Also, provide the current P/E ratio, P/B ratio, and dividend yield of Evergy, Inc.",
#   'date_str': '2023-03-24 15:20:01.735946'},
#  'HPE': {'symbol': 'HPE',
#   'query': "Please provide a breakdown of the company's revenue by business segment and any information on their research and development pipeline.",
#   'date_str': '2023-03-24 15:20:47.710161'},
#  'RMD': {'symbol': 'RMD',
#   'query': '- Market trends and forecasts for the respiratory medical equipment and software industry\n- Any significant changes in the competitive landscape for ResMed Inc., including new entrants to the industry and changes in market share\n- Potential future catalysts or disruptors for the industry or ResMed Inc. specifically',
#   'date_str': '2023-03-24 15:21:02.841990'},
#  'DHR': {'symbol': 'DHR',
#   'query': '"Danaher Corporation debt-to-equity ratio trend", "Competitors of Danaher Corporation in healthcare, diagnostics, and environmental markets"',
#   'date_str': '2023-03-24 15:21:25.375976'},
#  'JPM': {'symbol': 'JPM',
#   'query': "Please gather more information about JPMorgan Chase & Co.'s exposure to the recent turmoil in the financial sector, including the sharp pullback in European financial equities and the sell-off in Deutsche Bank.",
#   'date_str': '2023-03-25 19:25:22.955697'},
#  'PSX': {'symbol': 'PSX',
#   'query': '"Phillips 66 latest annual report" and "Phillips 66 competitors in the energy and petrochemical industries."',
#   'date_str': '2023-03-24 15:22:56.661734'},
#  'ADP': {'symbol': 'ADP',
#   'query': '"Automatic Data Processing, Inc. future growth prospects"',
#   'date_str': '2023-03-24 15:23:07.167667'},
#  'XOM': {'symbol': 'XOM',
#   'query': 'Please provide the current P/E ratio, dividend yield, and cash flow analysis of ExxonMobil Corporation.',
#   'date_str': '2023-03-24 15:23:19.329543'},
#  'PNW': {'symbol': 'PNW',
#   'query': "Please search for the latest regulatory developments regarding Pinnacle West Capital Corporation's operations in Arizona.",
#   'date_str': '2023-03-24 15:23:29.215132'},
#  'MMC': {'symbol': 'MMC',
#   'query': '1. News on Marsh & McLennan Companies, Inc. in the past month.\n2. Analyst recommendations for MMC stock.\n3. Trends in the insurance industry and potential implications for MMC.',
#   'date_str': '2023-03-24 15:23:56.882366'},
#  'SBUX': {'symbol': 'SBUX',
#   'query': "Please find any information about the company's expansion plans, consumer behavior trends, and direct competition.",
#   'date_str': '2023-03-24 15:24:15.690439'},
#  'UPS': {'symbol': 'UPS',
#   'query': "Please perform a search on the trend in e-commerce spending and home deliveries to update our understanding of the company's business outlook.",
#   'date_str': '2023-03-24 15:24:52.266390'},
#  'FIS': {'symbol': 'FIS',
#   'query': "What are the primary reasons for the company's recent deterioration of financial ratios, and is there any downside protection with its current market position?",
#   'date_str': '2023-03-24 15:25:05.644402'},
#  'AAPL': {'symbol': 'AAPL',
#   'query': "Could you please provide me with more information on Apple's product pipeline and any upcoming releases? Additionally, I would like to know if there are any concerns about supply chain disruptions or production delays that could impact the company's financials.",
#   'date_str': '2023-03-25 19:24:43.580854'},
#  'DTE': {'symbol': 'DTE',
#   'query': "1. Company's revenue trends over the last 5-10 years\n2. Competitors' financials\n3. Management's plans for growth and expansion",
#   'date_str': '2023-03-24 15:29:17.101204'},
#  'CME': {'symbol': 'CME',
#   'query': "Please provide information on the market competition for the financial exchange industry and CME Group's share of its respective markets.",
#   'date_str': '2023-03-24 15:29:58.127676'},
#  'CMA': {'symbol': 'CMA',
#   'query': '"Comerica Incorporated market trends and competitor analysis"',
#   'date_str': '2023-03-24 15:31:21.617012'},
#  'CINF': {'symbol': 'CINF',
#   'query': '"Cincinnati Financial Corporation Common Stock SWOT analysis"',
#   'date_str': '2023-03-24 15:34:31.523317'},
#  'META': {'symbol': 'META',
#   'query': "1. Can you gather more information about the security threats and data collection concerns that META is facing?\n2. Please provide an analysis of META's competition in the social media industry and how they compare in terms of market share and financial health.",
#   'date_str': '2023-03-25 19:26:48.365523'},
#  'CYBN': {'symbol': 'CYBN',
#   'query': 'Please provide the current market capitalization of CYBIN Inc. and the cash burn rate of the company.',
#   'date_str': '2023-03-25 19:28:51.190243'},
#  'JVA': {'symbol': 'JVA',
#   'query': "1. Could you please provide a detailed breakdown of Coffee Holding Co., Inc.'s revenue sources?\n2. Can we get further details on the nature of the restated financial statements and how much they differ from the original filings?\n3. What is the current state of the merger with The Jordre Well, LLC?",
#   'date_str': '2023-03-25 19:28:01.996552'},
#  'AMC': {'symbol': 'AMC',
#   'query': 'Please gather more information on the potential competition from Cineworld and any plans or initiatives AMC has in place to remain competitive in the market.',
#   'date_str': '2023-03-25 19:26:28.130098'},
#  'CS': {'symbol': 'CS',
#   'query': "1. Please provide the last four quarters of Credit Suisse Group's income statement.\n2. Please provide a detailed analysis of Credit Suisse Group's competitors and their financial performance.\n3. Please provide the current economic outlook and its potential impact on the financial services sector.",
#   'date_str': '2023-03-25 19:28:14.836702'},
#  'SPIR': {'symbol': 'SPIR',
#   'query': "1. What is the current state of the aviation industry, and how might this affect Spire Global's partnership with JetBlue Airways and contract with the FAA?\n2. What is the potential impact of the continued listing standards notice from NYSE on the company's stock price and future prospects?",
#   'date_str': '2023-03-25 19:28:33.268680'},
#  'LCID': {'symbol': 'LCID',
#   'query': "Please provide more information on Lucid Group, Inc.'s progress towards increasing its production capacity to 85,000 units per year by 2026.",
#   'date_str': '2023-03-25 19:25:04.484527'}}

# %%
for symbol in list(queries.keys())[:3]:
    query = queries[symbol]
    prompt = prompt_oracle.format(symbol=query['symbol'], gpt_query=query['query'], date_str=query['date_str'])
    print(prompt)
    oracle_response = query_openai(prompt, system_oracle, model="gpt-3.5-turbo", debug=False, max_tokens=300)
    print(oracle_response)
    print("="*45)
# Out:
# The following is a query the ticker symbol WEC:
# 1. Latest earnings call notes
# 2. Competitors' sales growth figures
# 3. Dividend history and payout ratio
#
# Dated: 2023-03-24 14:59:27.472868
#
# Dear Fantasia,
#
# Regarding your query for the ticker symbol WEC, here is the information you requested:
#
# 1. Latest earnings call notes:
#
# WEC Energy Group held its latest earnings call on February 16, 2023. During the call, the company reported earnings per share of $0.90, which beat analysts' estimates of $0.85. The company's revenue for the quarter was $2.1 billion, compared to the consensus estimate of $2.04 billion.
#
# 2. Competitors' sales growth figures:
#
# According to the latest available data, WEC Energy Group's competitors' sales growth figures are as follows:
# - Dominion Energy: 4.8%
# - Exelon: 1.7%
# - Duke Energy: 2.4%
# - Southern Company: 5.5%
#
# 3. Dividend history and payout ratio:
#
# WEC Energy Group has a dividend history of consistently paying dividends to its shareholders. Currently, the company offers an annual dividend yield of 2.87%. The payout ratio for the company is around 70%, indicating that the company is using approximately 70% of its earnings to pay dividends.
#
# I hope this information is useful to you. Please let me know if you need any further information.
#
# Best regards,
# Libra Anker
# =============================================
#
# The following is a query the ticker symbol PG:
# Please provide the latest updates on the company's marketing strategies and product innovations. Also, provide an overview of the competition in the consumer goods industry, with a focus on the companies that directly compete with Procter & Gamble.
#
# Dated: 2023-03-24 15:11:19.924480
#
# Dear Fantasia,
#
# Regarding your query on Procter & Gamble (PG), the company has been implementing various marketing strategies to enhance its products' appeal and expand its customer base. One such strategy is focusing on sustainable and environmentally friendly products, which has been gaining traction among consumers. PG has also been leveraging e-commerce to increase sales, and has been improving its online presence to attract more customers.
#
# In terms of product innovations, PG has been investing in research and development to create new and improved products in its various categories. For example, the company recently launched a new line of skincare products under the brand Olay, which focuses on natural ingredients and personalized routines.
#
# As for competition in the consumer goods industry, PG faces direct competition from companies such as Unilever, Colgate-Palmolive, and Johnson & Johnson. These companies also operate in various product categories, including personal care, home care, and beauty. They also have similar marketing strategies and innovations, making the industry highly competitive.
#
# However, PG has a strong brand reputation, loyal customer base, and a wide product portfolio, which gives it an advantage in the market. Additionally, the company's focus on sustainability and e-commerce has helped it differentiate itself from competitors.
#
# I hope this information is helpful for your report and decision-making.
#
# Best regards,
# Libra Anker
# =============================================
#
# The following is a query the ticker symbol AIG:
# Please provide a detailed analysis of AIG's recent business performance and future growth prospects. Also, provide the latest update on the interest rate environment and inflation trends.
#
# Dated: 2023-03-24 15:11:34.405238
#
# Dear Fantasia,
#
# Regarding your recent query about AIG, the company's recent business performance has been quite impressive. AIG has managed to show steady growth in its revenue and earnings over the last few quarters, primarily due to the growth in its general insurance segment. In the most recent quarter, AIG reported an EPS of $1.51, which was higher than the expected EPS of $1.00.
#
# In terms of future growth prospects, AIG is well-positioned to benefit from the increasing demand for insurance products, given its strong brand, diversified product portfolio, and global reach. The company has also been focusing on improving its underwriting performance and cost management to enhance profitability further.
#
# As for the interest rate environment, the Federal Reserve has recently indicated that it may raise interest rates in response to inflationary pressures. However, the timing and magnitude of such rate hikes are uncertain and depend on various economic factors. In terms of inflation, it has been rising in recent months due to supply chain disruptions, higher energy prices, and other factors. However, the Federal Reserve has indicated that it sees this as temporary and expects inflation to moderate in the medium term.
#
# I hope this information is helpful. Please let me know if you need any further details or clarification.
#
# Best Regards,
# Libra Anker
# =============================================

# %% [markdown]
# example:
#
# ```
# The following is a query the ticker symbol NVDA:
# Please gather further data on NVDA's dividend history, market competition, and supply chain risks.
#
# Dated: 2023-03-24 15:29:03.251108
#
# Dear Fantasia,
#
# Upon conducting a thorough analysis of NVDA, here are the requested details on its dividend history, market competition, and supply chain risks:
#
# Dividend History:
# NVDA has a relatively short dividend history as it only began paying dividends in 2012. Since then, the company has steadily increased its dividend payout, with a current yield of 0.14%. However, it's essential to note that NVDA's primary focus is on growth, and dividend payments are not its top priority.
#
# Market Competition:
# NVDA operates in a highly competitive market, with key competitors including Advanced Micro Devices (AMD), Intel (INTC), and Qualcomm (QCOM). While NVDA has managed to gain a significant market share in the gaming and data center markets, competitors are continually innovating and releasing new products, which could impact NVDA's market position.
#
# Supply Chain Risks:
# NVDA's supply chain is relatively complex, with the company relying on multiple suppliers for essential components. As such, there is always a risk of supply chain disruptions, particularly in times of global economic turbulence or geopolitical tensions. Any disruptions could result in production delays, which could ultimately impact NVDA's financial performance.
#
# I hope this information helps in your assessment of NVDA.
#
# Regards,
# Libra Anker
# ```

# %% [markdown]
# ## token optimizing a previous prompt

# %% [markdown]
# ## token optimizing a too-long prompt

# %% [markdown]
# ## Loop 2

# %%
system_vanilla = '''
You are Fantasia Goldfang, a financial advisor for higher-income working professionals. Your clients want to invest their portfolio in stocks, 
and your job is to take in financial information and give investment advice. 

Every day, your client Montgomery Frostam will query you, and you will decide what to do with his portfolio assets. Your strategy tends to 
center around a company's fundamental value rather than responding to noisy market fluctuations. You should aim to be well-diversified across 
companies and industries: no one company should be a significant fraction of Mr. Frostam's portfolio. When you buy, don't spend more than 5% 
of the total value of the portfolio unless it is truly an exceptional value proposition.

Mr. Frostam's query will include the company's name, a description, the price of its stock, possibly some recent news, and relevant company 
financial statistics. You will also receive information about Montgomery Frostam's portfolio, including how much stock of the current company 
he might hold. You will then respond with the following structured response:

Analysis: (your analysis of the current health of the company, and what its stock's true value might be)
Risk level: (low, medium, or high)
Information requests: (a succinct prompt for your market analyst, Libra Anker, to search additional data for your decision, phrased in the form of a command)
Verdict: (buy, hold, pass, or sell) X (if a buy or sell, X is how many to buy/sell)
'''

# %%
prompt_template = '''
Company: {company}
Ask price: {ask_price}
Bid price: {bid_price}
full trading data (Alpaca Market API, get_stock_snapshot):
{trading_data}

last annual income statement for {company} (Financial Modeling Prep API):
{quarterly_data}

previous annual income statement for {company} (Financial Modeling Prep API):
{quarterly_data_1yr}

last 12 months of the Consumer Price Index (Financial Modeling Prep API):
{cpi_data}

stock price change data for {company} (Financial Modeling Prep API):
{stock_change_data}

Recent news (Benzinga news service):
{news}

Analysis by Libra Anker:
{analysis}

Montgomery Frostam's portfolio 
{company} stock owned: {stock_owned} (${stock_value} value)
Portfolio cash available: ${cash}
Portfolio total value: ${total_value}
'''

# %%
import fmp_utils
import alpaca_utils

# %%
import os
from datetime import datetime
def write_log(s):
    try:
        with open('log.md') as f:
            txt = f.read()
    except:
        txt = ""
    with open('_log.md', 'w') as f:
        f.write(txt + '\n' + s)
    os.rename('_log.md', 'log.md')

# %%
def write_notes(symbol, decision):
    try:
        with open('notes.json') as f:
            j = json.loads(f.read())
    except:
        j = {}
    if symbol not in j:
        j[symbol] = []
    j[symbol].append({ 'note': decision, 'date': str(datetime.now()) })
    with open('_notes.json', 'w') as f:
        f.write(json.dumps(j, indent='  '))
    os.rename('_notes.json', 'notes.json')
    
def get_notes(symbol):
    try:
        with open('notes.json') as f:
            j = json.loads(f.read())
    except:
        j = {}
    notes = ""
    if symbol in j:
        for item in j[symbol]:
            notes += f"{item['date']}\n{item['note'].strip()}"
    return notes
# print(get_notes('NVDA'))

# %%
def get_analysis(decision):
    analysis = decision.split('Risk level:')[0].replace('Analysis:', '')
    return analysis

# %%
def get_verdict(decision, symbol):
    # should return { 'verdict': 'buy|sell|hold|pass', 'amount': X }
    decision = decision.lower()
    verdict_par = decision.split('verdict:')[1].strip()
    verdict = verdict_par.split(' ')[0]
    for char in set('!.'):
        verdict = verdict.replace(char, '')
    if verdict not in ('buy', 'sell', 'hold', 'pass'):
        raise Exception(verdict + ' not valid!')
    if verdict in ('buy', 'sell'):
        amount = verdict_par.split(' ')[1]
    else:
        amount = 0
    return { 'verdict': verdict, 'amount': int(amount), 'symbol': symbol }

def handle_verdict(verdict, portfolio):
    spending_cap = 1000
    
    if verdict['verdict'] in ('hold', 'pass'):
        return
    symbol = get_symbol(verdict['guild'])
    if verdict['verdict'] == 'sell' and verdict['amount'] > portfolio[symbol]['held']:
        print(f"can't sell {verdict['amount']} {symbol}, only own {portfolio[symbol]['held']}")
    quote = get_quote(symbol)
    if verdict['amount'] * quote > spending_cap:
        verdict['amount'] = int(spending_cap / quote)
        print('capping trade at', verdict['amount'], symbol)
    trade(symbol, verdict['verdict'], verdict['amount'])
    return update_portfolio(portfolio, verdict)

# %%
def count_tokens(s, divisor=3):
    # placeholder until I make / get something better, maybe, unless this is good enough
    return int(len(s) / divisor)

# %%
portfolio = alpaca_utils.get_portfolio()
cpi_data = [{'date': '2023-02-01', 'value': 301.648}, {'date': '2023-01-01', 'value': 300.536}, {'date': '2022-12-01', 'value': 298.99}, {'date': '2022-11-01', 'value': 298.598}, {'date': '2022-10-01', 'value': 297.987}, {'date': '2022-09-01', 'value': 296.539}, {'date': '2022-08-01', 'value': 295.32}, {'date': '2022-07-01', 'value': 294.628}, {'date': '2022-06-01', 'value': 294.728}, {'date': '2022-05-01', 'value': 291.268}, {'date': '2022-04-01', 'value': 288.611}, {'date': '2022-03-01', 'value': 287.472}]
write_log('# ' + str(datetime.now()))
news_dict = get_news_dict() # get symbols with recent news
symbols_with_news = list(news_dict.keys())
random.shuffle(symbols_with_news)

for symbol in symbols_with_news:
    write_log('\n## ' + symbol)
    news_list = news_dict[symbol]
    
    # get financial information
    asset_data = alpaca_utils.get_asset(symbol)
    try:
        snapshot_data = alpaca_utils.get_snapshot(symbol)
    except:
        print(symbol, "snapshot not found")
        continue
    del snapshot_data[symbol].daily_bar
    del snapshot_data[symbol].previous_daily_bar
    quote = snapshot_data[symbol].latest_quote
    quarterly = fmp_utils.get_financials(symbol)
    quarterly_1yr = fmp_utils.get_financials(symbol, 1)
    stock_change = fmp_utils.get_simple_stock_changes(symbol)

    # get news and analysis
    oracle_request = queries[symbol] if symbol in queries else None
    if oracle_request:
        oracle_prompt = prompt_oracle.format(symbol=oracle_request['symbol'], gpt_query=oracle_request['query'], date_str=oracle_request['date_str'])
        oracle_response = query_openai(oracle_prompt, system_oracle, model="gpt-3.5-turbo", debug=False, max_tokens=300)
    else:
        oracle_response = '(none)'
        print('no oracle request', symbol)
        continue
    # news = summarize_news_list(news_list)
    news = alpaca_utils.get_news_summary(symbol) # gets more news
    notes = get_notes(symbol)
    notes = get_analysis(get_notes(symbol))
    if len(notes) == 0:
        print('no notes!', symbol)
        continue
    # notes = '(none)' # need to remove info request, and just keep verdict
    stock_owned = portfolio[symbol]['held'] if symbol in portfolio else 0
    prompt = prompt_template.format(
        company=asset_data.name, news=news, 
        ask_price=quote.ask_price, 
        bid_price=quote.bid_price, 
        trading_data=snapshot_data[symbol].json(), 
        quarterly_data=quarterly,
        stock_change_data=stock_change, 
        quarterly_data_1yr=quarterly_1yr, 
        cpi_data=str(cpi_data),
        stock_owned=stock_owned, 
        stock_value=stock_owned * float(quote.bid_price), 
        cash=portfolio['cash'], 
        total_value=portfolio['value'], 
        analysis=oracle_response)
    if len(notes) > 0:
        prompt += f"\n\nYour previous notes on {asset_data.name}:\n{notes}"
    print("** tokens:", count_tokens(system_vanilla+prompt))
    try:
        decision = query_openai(prompt, system_vanilla, model="gpt-3.5-turbo", debug=True)
    except Exception as e:
        print(e)
        continue
    write_log(decision)
    write_notes(symbol, decision)
    print(get_verdict(decision, symbol))
    # new_portfolio = handle_verdict(get_verdict(decision, symbol), portfolio)
    print("~"*45)
    # if new_portfolio['cash'] <= 0:
    #     break
# Out:
# no oracle request SHOP
# CNNWQ snapshot not found
# ** tokens: 3178
# ~ prompt:
# Company: Apple Inc. Common Stock
# Ask price: 0.0
# Bid price: 0.0
# full trading data (Alpaca Market API, get_stock_snapshot):
# {"symbol": "AAPL", "latest_trade": {"symbol": "AAPL", "timestamp": "2023-03-24T19:59:58.800099+00:00", "exchange": "V", "price": 160.25, "size": 200.0, "id": 7348, "conditions": ["@"], "tape": "C"}, "latest_quote": {"symbol": "AAPL", "timestamp": "2023-03-24T20:00:00.000522+00:00", "ask_exchange": "V", "ask_price": 0.0, "ask_size": 0.0, "bid_exchange": "V", "bid_price": 0.0, "bid_size": 0.0, "conditions": ["R"], "tape": "C"}, "minute_bar": {"symbol": "AAPL", "timestamp": "2023-03-24T19:59:00+00:00", "open": 160.18, "high": 160.34, "low": 160.09, "close": 160.25, "volume": 24805.0, "trade_count": 229.0, "vwap": 160.18847}}
#
# last annual income statement for Apple Inc. Common Stock (Financial Modeling Prep API):
# {'date': '2022-09-24', 'symbol': 'AAPL', 'reportedCurrency': 'USD', 'cik': '0000320193', 'fillingDate': '2022-10-27', 'acceptedDate': '2022-10-27 18:01:14', 'calendarYear': '2022', 'period': 'FY', 'revenue': 394328000000, 'costOfRevenue': 223546000000, 'grossProfit': 170782000000, 'grossProfitRatio': 0.43309630561360085, 'researchAndDevelopmentExpenses': 26251000000, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 25094000000, 'otherExpenses': 0, 'operatingExpenses': 51345000000, 'costAndExpenses': 274891000000, 'interestIncome': 2825000000, 'interestExpense': 2931000000, 'depreciationAndAmortization': 11104000000, 'ebitda': 133138000000, 'ebitdaratio': 0.33763263070337385, 'operatingIncome': 119437000000, 'operatingIncomeRatio': 0.30288744395528594, 'totalOtherIncomeExpensesNet': -334000000, 'incomeBeforeTax': 119103000000, 'incomeBeforeTaxRatio': 0.30204043334482966, 'incomeTaxExpense': 19300000000, 'netIncome': 99803000000, 'netIncomeRatio': 0.2530964070519973, 'eps': 6.15, 'epsdiluted': 6.11, 'weightedAverageShsOut': 16215963000, 'weightedAverageShsOutDil': 16325819000, 'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924.htm'}
#
# previous annual income statement for Apple Inc. Common Stock (Financial Modeling Prep API):
# {'date': '2021-09-25', 'symbol': 'AAPL', 'reportedCurrency': 'USD', 'cik
# 2023-03-24T13:29:51Z: Apple Supplier Eyes Second India Factory To Assemble Latest iPhones – summary: Apple Inc&#39;s (NASDAQ: AAPL) Taiwanese supplier Pegatron Corp (OTC: PGTRF) weighs a second factory in India.
# 2023-03-24T12:43:10Z: Could Tesla's Wireless Charger Be The Ultimate Solution To Apple's AirPower Mat?
# 2023-03-24T04:10:37Z: Twitter To Remove Legacy Verified Checkmarks From April 1: 'Elon Wants Your Money Or Your Blue Tick' – summary: Starting April 1, Elon Musk‘s Twitter will remove the traditional blue checkmarks from user accounts as it gradually phases out its long-standing verification program, Twitter Blue.
# 2023-03-24T10:47:05Z: Apple Watch Could Get Bigger With Camera Upgrade For Better Photography: What The Latest Patent Application Suggests
# 2023-03-24T09:45:29Z: S&P 500 Settles Higher, Market Volatility Increases Further – summary: The S&amp;P 500 settled higher on Thursday as U.S. Treasury Secretary Janet Yellen said that regulators are prepared to take additional steps to protect customer bank deposits if necessary.  The Federal Reserve increased interest rates by a quarter of a percentage point to 4.75%-5% at its March meeting.
#
#
# Analysis by Libra Anker:
# Dear Fantasia,
#
# Regarding your query on the ticker symbol AAPL, there are currently no known upcoming changes in regulations or policies in China that could significantly impact Apple's business operations. However, it's important to note that China remains a key market for Apple, and any significant policy shifts in the country could have potential repercussions for the company's financial performance in the future.
#
# Please let me know if you need any further information.
#
# Best regards,
# Libra Anker
#
# Montgomery Frostam's portfolio
# Apple Inc. Common Stock stock owned: 0 ($0.0 value)
# Portfolio cash available: $-14132.49
# Portfolio total value: $100270.14
#
#
# Your previous notes on Apple Inc. Common Stock:
# 2023-03-24 15:25:19.513891
#  Apple Inc. is a leading tech company that designs, produces, and sells consumer electronics, computer software, and online services. The company has a strong brand and a loyal consumer base, which has helped its financials improve. Apple's latest quarterly report shows a strong revenue of $117.15 billion and a solid net income of $29.99 billion. However, the company's gross profit ratio has decreased to 42.96% compared to the previous quarter. On the positive side, Apple has a low level of debt and a good cash balance. Given Apple's financials and market position, the stock's true value is likely around $160.
#
#
# ~ response: Analysis:
# Apple Inc. is a leading tech company with a strong brand and a loyal consumer base. The company's latest quarterly report shows solid revenue and net income, but the gross profit ratio has decreased compared to the previous quarter. Despite this, Apple has a low level of debt and a good cash balance. Based on these factors, the stock's true value is likely around $160.
#
# Risk level:
# Medium
#
# Information requests:
# Could you please provide me with more information on Apple's product pipeline and any upcoming releases? Additionally, I would like to know if there are any concerns about supply chain disruptions or production delays that could impact the company's financials.
#
# Verdict:
# Hold
# ~
# {'verdict': 'hold', 'amount': 0, 'symbol': 'AAPL'}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# no oracle request GHRS
# ** tokens: 3458
# ~ prompt:
# Company: Lucid Group, Inc. Common Stock
# Ask price: 0.0
# Bid price: 0.0
# full trading data (Alpaca Market API, get_stock_snapshot):
# {"symbol": "LCID", "latest_trade": {"symbol": "LCID", "timestamp": "2023-03-24T19:59:51.990753+00:00", "exchange": "V", "price": 8.18, "size": 300.0, "id": 1367, "conditions": ["@"], "tape": "C"}, "latest_quote": {"symbol": "LCID", "timestamp": "2023-03-24T20:00:00.005676+00:00", "ask_exchange": "V", "ask_price": 0.0, "ask_size": 0.0, "bid_exchange": "V", "bid_price": 0.0, "bid_size": 0.0, "conditions": ["R"], "tape": "C"}, "minute_bar": {"symbol": "LCID", "timestamp": "2023-03-24T19:59:00+00:00", "open": 8.175, "high": 8.18, "low": 8.175, "close": 8.18, "volume": 6477.0, "trade_count": 26.0, "vwap": 8.179318}}
#
# last annual income statement for Lucid Group, Inc. Common Stock (Financial Modeling Prep API):
# {'date': '2022-12-31', 'symbol': 'LCID', 'reportedCurrency': 'USD', 'cik': '0001811210', 'fillingDate': '2023-02-28', 'acceptedDate': '2023-02-28 16:09:35', 'calendarYear': '2022', 'period': 'FY', 'revenue': 608181000, 'costOfRevenue': 1646086000, 'grossProfit': -1037905000, 'grossProfitRatio': -1.706572549948124, 'researchAndDevelopmentExpenses': 821512000, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 734574000, 'otherExpenses': 0, 'operatingExpenses': 1556086000, 'costAndExpenses': 3202172000, 'interestIncome': 56756000, 'interestExpense': 30596000, 'depreciationAndAmortization': 222203000, 'ebitda': -1051282000, 'ebitdaratio': -1.7285676468025144, 'operatingIncome': -2593991000, 'operatingIncomeRatio': -4.265162838036703, 'totalOtherIncomeExpensesNet': 1289910000, 'incomeBeforeTax': -1304081000, 'incomeBeforeTaxRatio': -2.1442317336450825, 'incomeTaxExpense': 379000, 'netIncome': -1304460000, 'netIncomeRatio': -2.144854903392247, 'eps': -0.78, 'epsdiluted': -0.77, 'weightedAverageShsOut': 1678346079, 'weightedAverageShsOutDil': 1693258608, 'link': 'https://www.sec.gov/Archives/edgar/data/1811210/000162828023005540/0001628280-23-005540-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1811210/000162828023005540/lcid-20221231.htm'}
#
# previous annual income statement for Lucid Group, Inc. Common Stock (Financial Modeling Prep API):
# {'date': '2021-12-31', 'symbol': 'LCID', 'reportedCurrency': 'USD', 'cik': '0001811210', 'fillingDate': '2022-02-28', 'acceptedDate': '2022-02-28 16:27:56', 'calendarYear': '2021', 'period': 'FY', 'revenue': 27111000, 'costOfRevenue': 154897000, 'grossProfit': -127786000, 'grossProfitRatio': -4.713437350153074, 'researchAndDevelopmentExpenses': 750185000, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 652475000, 'otherExpenses': 0, 'operatingExpenses': 1402660000, 'costAndExpenses': 1557557000, 'interestIncome': 0, 'interestExpense': 1374000, 'depreciationAndAmortization': 62907000, 'ebitda': -2515431000, 'ebitdaratio': -92.7826712404559, 'operatingIncome': -1530446000, 'operatingIncomeRatio': -56.451108406181994, 'totalOtherIncomeExpensesNet': -1049266000, 'incomeBeforeTax': -2579712000, 'incomeBeforeTaxRatio': -95.1537014495961, 'incomeTaxExpense': 49000, 'netIncome': -2579761000, 'netIncomeRatio': -95.1555088340526, 'eps': -3.4843094888918427, 'epsdiluted': -3.4843094888918427, 'weightedAverageShsOut': 740393759, 'weightedAverageShsOutDil': 740393759, 'link': 'https://www.sec.gov/Archives/edgar/data/1811210/000162828022004253/0001628280-22-004253-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/
# Lucid Group, Inc. is primarily competing against Tesla, Inc., General Motors, and Ford Motor Company in the electric vehicle market. Tesla has been leading the market with its Model S, Model X, and Model 3, while General Motors and Ford have also launched their own electric vehicle models. Lucid Group, Inc.'s main competitive advantage is its innovative technology, which enables longer battery life and faster charging times.
#
# Production Capacity:
# Lucid Group, Inc.'s production capacity is currently at 34,000 units annually at its plant in Arizona. The company aims to increase it to 85,000 units per year by 2026 as it ramps up production of its luxury sedan, the Lucid Air.
#
# Updates on Financial Situation:
# Lucid Group, Inc. recently reported its fourth-quarter and full-year 2022 financial results. The company's revenue for the full year was $2.2 billion, which surpassed its previous guidance of $1.9 billion. However, it reported a net loss of $1.8 billion for the year. In the fourth quarter, the company delivered 5,200 units of the Lucid Air, which was higher than its previous guidance of 4,800 units. The company also reported an operating loss of $497 million and a net loss of $624 million for the quarter. Despite the losses, Lucid
#
# Montgomery Frostam's portfolio
# Lucid Group, Inc. Common Stock stock owned: 0 ($0.0 value)
# Portfolio cash available: $-14132.49
# Portfolio total value: $100270.14
#
#
# Your previous notes on Lucid Group, Inc. Common Stock:
# 2023-03-25 19:19:48.155080
#  Lucid Group, Inc. is an electric vehicle manufacturer that has been gaining popularity in the market. However, according to the last income statement, the company is still operating at a loss, and its gross profit ratio is negative. Additionally, the stock price has been volatile, with a significant drop in the past six months. While the recent news mentions some positive developments, such as a partnership with Apple, there is not enough information to determine their impact on the company's fundamentals. Overall, while Lucid Group, Inc. has potential, it is still a risky investment.
#
#
# ~ response: Analysis:
# Lucid Group, Inc. is a company that operates in the electric vehicle market and is competing with big players like Tesla, General Motors, and Ford. The company has been gaining popularity due to its innovative technology that enables longer battery life and faster charging times. However, according to the last income statement, the company is still operating at a loss, and its gross profit ratio is negative. The recent news mentions some positive developments, but it is not enough to determine their impact on the company's fundamentals. Overall, Lucid Group, Inc. has potential, but it is still a risky investment.
#
# Risk level:
# High
#
# Information requests:
# Please provide more information on Lucid Group, Inc.'s progress towards increasing its production capacity to 85,000 units per year by 2026.
#
# Verdict:
# Hold
# ~
# {'verdict': 'hold', 'amount': 0, 'symbol': 'LCID'}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# no oracle request GOOGL
# ** tokens: 3238
# ~ prompt:
# Company: JPMorgan Chase & Co.
# Ask price: 0.0
# Bid price: 0.0
# full trading data (Alpaca Market API, get_stock_snapshot):
# {"symbol": "JPM", "latest_trade": {"symbol": "JPM", "timestamp": "2023-03-24T19:59:56.170366+00:00", "exchange": "V", "price": 124.92, "size": 100.0, "id": 59620106716533, "conditions": [" "], "tape": "A"}, "latest_quote": {"symbol": "JPM", "timestamp": "2023-03-24T20:00:00.003650+00:00", "ask_exchange": "V", "ask_price": 0.0, "ask_size": 0.0, "bid_exchange": "V", "bid_price": 0.0, "bid_size": 0.0, "conditions": ["R"], "tape": "A"}, "minute_bar": {"symbol": "JPM", "timestamp": "2023-03-24T19:59:00+00:00", "open": 124.95, "high": 124.95, "low": 124.83, "close": 124.92, "volume": 19466.0, "trade_count": 111.0, "vwap": 124.903686}}
#
# last annual income statement for JPMorgan Chase & Co. (Financial Modeling Prep API):
# {'date': '2022-12-31', 'symbol': 'JPM', 'reportedCurrency': 'USD', 'cik': '0000019617', 'fillingDate': '2023-02-21', 'acceptedDate': '2023-02-21 16:13:55', 'calendarYear': '2022', 'period': 'FY', 'revenue': 128695000000, 'costOfRevenue': 0, 'grossProfit': 128695000000, 'grossProfitRatio': 1, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses':
# Portfolio cash available: $-14132.49
# Portfolio total value: $100270.14
#
#
# Your previous notes on JPMorgan Chase & Co.:
# 2023-03-24 15:22:33.905465
#
# JPMorgan Chase & Co. is a leading financial institution with a strong presence in investment banking, commercial banking, and asset management. The company has shown consistent growth in revenue and net income, as seen in its latest quarterly report. However, the company's stock price has been on a decline in the short-term due to rising interest rates and concerns about inflation. Nevertheless, JPM remains a well-managed company with strong fundamentals and a diverse portfolio of businesses.
#
#
# ~ response: Analysis: JPMorgan Chase & Co. is a global financial services company that serves a broad range of clients in various industries. The company has shown consistent growth in revenue and net income, as seen in its latest annual report. Despite the recent decline in its stock price due to rising interest rates and concerns about inflation, JPM remains a well-managed company with strong fundamentals and a diverse portfolio of businesses. We believe that the company's true value is higher than its current stock price.
#
# Risk level: Medium
#
# Information requests: Please gather more information about JPMorgan Chase & Co.'s exposure to the recent turmoil in the financial sector, including the sharp pullback in European financial equities and the sell-off in Deutsche Bank.
#
# Verdict: Hold. While we believe that JPMorgan Chase & Co.'s true value is higher than its current stock price, we recommend holding onto the stock for now due to the medium risk level and recent financial sector turmoil. We will continue to monitor the situation and re-evaluate our recommendation as more information becomes available.
# ~
# {'verdict': 'hold', 'amount': 0, 'symbol': 'JPM'}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ** tokens: 3074
# ~ prompt:
# Company: MANCHESTER UNITED PLC
# Ask price: 0.0
# Bid price: 0.0
# full trading data (Alpaca Market API, get_stock_snapshot):
# {"symbol": "MANU", "latest_trade": {"symbol": "MANU", "timestamp": "2023-03-24T19:59:45.730292+00:00", "exchange": "V", "price": 23.92, "size": 400.0, "id": 59619319233099, "conditions": [" "], "tape": "A"}, "latest_quote": {"symbol": "MANU", "timestamp": "2023-03-24T20:00:00.003760+00:00", "ask_exchange": "V", "ask_price": 0.0, "ask_size": 0.0, "bid_exchange": "V", "bid_price": 0.0, "bid_size": 0.0, "conditions": ["R"], "tape": "A"}, "minute_bar": {"symbol": "MANU", "timestamp": "2023-03-24T19:59:00+00:00", "open": 23.99, "high": 23.99, "low": 23.92, "close": 23.92, "volume": 2157.0, "trade_count": 15.0, "vwap": 23.951834}}
#
# last annual income statement for MANCHESTER UNITED PLC (Financial Modeling Prep API):
# {'date': '2022-06-30', 'symbol': 'MANU', 'reportedCurrency': 'GBP', 'cik': '0001549107', 'fillingDate': '2022-06-30', 'acceptedDate': '2022-06-29 20:00:00', 'calendarYear': '2022', 'period': 'FY', 'revenue': 583201000, 'costOfRevenue': 0, 'grossProfit': 0, 'grossProfitRatio': 0, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 0, 'otherExpenses': 692520000, 'operatingExpenses': 692520000, 'costAndExpenses': 692520000, 'interestIncome': 23676000, 'interestExpense': 85915000, 'depreciationAndAmortization': 165776000, 'ebitda': 102068000, 'ebitdaratio': 0.17501341732953132, 'operatingIncome': -87384000, 'operatingIncomeRatio': -0.14983513402754797, 'totalOtherIncomeExpensesNet': -62239000, 'incomeBeforeTax': -149623000, 'incomeBeforeTaxRatio': -0.25655477271129506, 'incomeTaxExpense': -34113000, 'netIncome': -115510000, 'netIncomeRatio': -0.19806207465350711, 'eps': -0.708915606453949, 'epsdiluted': -0.708915606453949, 'weightedAverageShsOut': 162939000, 'weightedAverageShsOutDil': 162939000, 'link': '', 'finalLink': ''}
#
# previous annual income statement for MANCHESTER UNITED PLC (Financial Modeling Prep API):
# {'date': '2021-06-30', 'symbol': 'MANU', 'reportedCurrency': 'GBP', 'cik': '0001549107', 'fillingDate': '2021-06-30', 'acceptedDate': '2021-06-29 20:00:00', 'calendarYear': '2021', 'period': 'FY', 'revenue': 494117000, 'costOfRevenue': 0, 'grossProfit': 0, 'grossProfitRatio': 0, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 334805000, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 334805000, 'otherExpenses': 202745000, 'operatingExpenses': 537550000, 'costAndExpenses': 537550000, 'interestIncome': 3000, 'interestExpense': 20215000, 'depreciationAndAmortization': 139357000, 'ebitda': 135545000, 'ebitdaratio': 0.2743176211302181, 'operatingIncome': -36926000, 'operatingIncomeRatio': -0.07473128833859187, 'totalOtherIncomeExpensesNet': 12899000, 'incomeBeforeTax': -24027000, 'incomeBeforeTaxRatio': -0.04862613510565311, 'incomeTaxExpense': 68189000, 'netIncome': -92216000, 'netIncomeRatio': -0.18662786344124974, 'eps': -0.566, 'epsdiluted': -0.566, 'weightedAverageShsOut': 162939000, 'weightedAverageShsOutDil': 162939000, 'link': '', 'finalLink': ''}
#
# last 12 months of the Consumer Price Index (Financial Modeling Prep API):
# [{'date': '2023-02-01', 'value': 301.648}, {'date': '2023-01-01', 'value': 300.536}, {'date': '2022-12-01', 'value': 298.99}, {'date': '2022-11-01', 'value': 298.598}, {'date': '2022-10-01', 'value': 297.987}, {'date': '2022-09-01', 'value': 296.539}, {'date': '2022-08-01', 'value': 295.32}, {'date': '2022-07-01', 'value': 294.628}, {'date': '2022-06-01', 'value': 294.728}, {'date': '2022-05-01', 'value': 291.268}, {'date': '2022-04-01', 'value': 288.611}, {'date': '2022-03-01', 'value': 287.472}]
#
# stock price change data for MANCHESTER UNITED PLC (Financial Modeling Prep API):
# [{'symbol': 'MANU', '1D': 0.6734, '5D': 6.31111, '1M': 4.49979, '3M': 6.40569, '6M': 83.01454, 'ytd': 5.09666, '1Y': 69.30684, '3Y': 58.73016, '5Y': 33.32604, '10Y': 53.40719, 'max': 84.30777}]
#
# Recent news (Benzinga news service):
# 2023-03-25T12:18:21Z: Sky News Reported Earlier: Manchester United Received A Fresh Overnight Bid From Qatari  Sheikh Jassim Bin Hamad Al Thani, Who Had Requested A Deadline Extension On Wednesday
# 2023-03-24T16:43:33Z: Sportico Tweets "Al Thani's Most Recent Bid For The Team Appears To Be In The Ballpark Of £6B ($7.3B), The Amount The Glazer Family Is Asking For Manchester United. Jim Ratcliffe Revised His Offer Of £5B ($6.12B + Debt) But Could Not Match Al Thani's Offer"
# 2023-03-24T08:49:10Z: UK's The Independent Reported Thursday: Elliott Management Have Made An Offer To Buy A Minority Stake Of Manchester United
}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ITHUF snapshot not found
# no oracle request CRM
# no oracle request MSFT
# no oracle request ATAI
# no oracle request SEEL
# SHIBUSD snapshot not found
# no oracle request UBS
# no oracle request FITB
# []
# []
# no oracle request ARKF
# ** tokens: 3056
# ~ prompt:
# Company: Oracle Corp
# Ask price: 0.0
# Bid price: 0.0
# full trading data (Alpaca Market API, get_stock_snapshot):
# {"symbol": "ORCL", "latest_trade": {"symbol": "ORCL", "timestamp": "2023-03-24T19:59:58.092481+00:00", "exchange": "V", "price": 88.02, "size": 200.0, "id": 59620225480788, "conditions": [" "], "tape": "A"}, "latest_quote": {"symbol": "ORCL", "timestamp": "2023-03-24T20:00:00.004614+00:00", "ask_exchange": "V", "ask_price": 0.0, "ask_size": 0.0, "bid_exchange": "V", "bid_price": 0.0, "bid_size": 0.0, "conditions": ["R"], "tape": "A"}, "minute_bar": {"symbol": "ORCL", "timestamp": "2023-03-24T19:59:00+00:00", "open": 88.01, "high": 88.02, "low": 87.95, "close": 88.02, "volume": 6974.0, "trade_count": 71.0, "vwap": 87.97565}}
#
# last annual income statement for Oracle Corp (Financial Modeling Prep API):
# {'date': '2022-05-31', 'symbol': 'ORCL', 'reportedCurrency': 'USD', 'cik': '0001341439', 'fillingDate': '2022-06-21', 'acceptedDate': '2022-06-21 08:04:37', 'calendarYear': '2022', 'period': 'FY', 'revenue': 42440000000, 'costOfRevenue': 8877000000, 'grossProfit': 33563000000, 'grossProfitRatio': 0.7908341187558907, 'researchAndDevelopmentExpenses': 7219000000, 'generalAndAdministrativeExpenses': 1317000000, 'sellingAndMarketingExpenses': 8047000000, 'sellingGeneralAndAdministrativeExpenses': 9364000000, 'otherExpenses': 5844000000, 'operatingExpenses': 22427000000, 'costAndExpenses': 31304000000, 'interestIncome': 94000000, 'interestExpense': 2755000000, 'depreciationAndAmortization': 3122000000, 'ebitda': 13526000000, 'ebitdaratio': 0.3187087653157399, 'operatingIncome': 10926000000, 'operatingIncomeRatio': 0.2574458058435438, 'totalOtherIncomeExpensesNet': -3277000000, 'incomeBeforeTax': 7649000000, 'incomeBeforeTaxRatio': 0.18023091423185675, 'incomeTaxExpense': 932000000, 'netIncome': 6717000000, 'netIncomeRatio': 0.15827049952874647, 'eps': 2.49, 'epsdiluted': 2.41, 'weightedAverageShsOut': 2700000000, 'weightedAverageShsOutDil': 2786000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1341439/000156459022023675/0001564590-22-023675-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1341439/000156459022023675/orcl-10k_20220531.htm'}
#
# previous annual income statement for Oracle Corp (Financial Modeling Prep API):
# {'date': '2021-05-31', 'symbol': 'ORCL', 'reportedCurrency': 'USD', 'cik': '0001341439', 'fillingDate': '2021-06-21', 'acceptedDate': '2021-06-21 16:10:31', 'calendarYear': '2021', 'period': 'FY', 'revenue': 40479000000, 'costOfRevenue': 7855000000, 'grossProfit': 32624000000, 'grossProfitRatio': 0.805948763556412, 'researchAndDevelopmentExpenses': 6527000000, 'generalAndAdministrativeExpenses': 1254000000, 'sellingAndMarketingExpenses': 7682000000, 'sellingGeneralAndAdministrativeExpenses': 8936000000, 'otherExpenses': 1508000000, 'operatingExpenses': 16971000000, 'costAndExpenses': 24826000000, 'interestIncome': 101000000, 'interestExpense': 2496000000, 'depreciationAndAmortization': 2916000000, 'ebitda': 18411000000, 'ebitdaratio': 0.4548284295560661, 'operatingIncome': 15213000000, 'operatingIncomeRatio': 0.3758245015934188, 'totalOtherIncomeExpensesNet': -2214000000, 'incomeBeforeTax': 12999000000, 'incomeBeforeTaxRatio': 0.3211294745423553, 'incomeTaxExpense': -747000000, 'netIncome': 13746000000, 'netIncomeRatio': 0.3395834877343808, 'eps': 4.67, 'epsdiluted': 4.55, 'weightedAverageShsOut': 2945000000, 'weightedAverageShsOutDil': 3022000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1341439/000156459021033616/0001564590-21-033616-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1341439/000156459021033616/orcl-10k_20210531.htm'}
#
# last 12 months of the Consumer Price Index (Financial Modeling Prep API):
# [{'date': '2023-02-01', 'value': 301.648}, {'date': '2023-01-01', 'value': 300.536}, {'date': '2022-12-01', 'value': 298.99}, {'date': '2022-11-01', 'value': 298.598}, {'date': '2022-10-01', 'value': 297.987}, {'date': '2022-09-01', 'value': 296.539}, {'date': '2022-08-01', 'value': 295.32}, {'date': '2022-07-01', 'value': 294.628}, {'date': '2022-06-01', 'value': 294.728}, {'date': '2022-05-01', 'value': 291.268}, {'date': '2022-04-01', 'value': 288.611}, {'date': '2022-03-01', 'value': 287.472}]
#
# stock price change data for Oracle Corp (Financial Modeling Prep API):
# [{'symbol': 'ORCL', '1D': 0.262, '5D': 3.20122, '1M': -0.73314231, '3M': 9.26409, '6M': 37.55867, 'ytd': 5.51841, '1Y': 9.55606, '3Y': 101.24433, '5Y': 105.66514, '10Y': 227.63609, 'max': 167717.10014}]
#
# Recent news (Benzinga news service):
# 2023-03-25T15:25:10Z: Barron's Top Weekend Stock Picks: Oracle, Costco, Ford And Odds Of Microsoft-Activision Deal Just Got Much Better – summary: Benzinga reviews this weekend&#39;s top stories covered by Barron&#39;s. Here are the articles investors need to read.
# 2023-03-24T19:13:44Z: Is TikTok A Threat? Why Congress Is Freaking Out Over Alleged Data Collection – summary: Elected officials from both sides of the aisle have grown concerned with social media app TikTok and the amount of user data it collects.
# 2023-03-24T16:00:20Z: Where Oracle Stands With Analysts
# 2023-03-24T12:37:14Z: This Delivery Giant Is A 'Comeback Story' Plus Nike, AbbVie And Oracle: CNBC's 'Final Trades' – summary: On CNBC’s &#34;Halftime Report Final Trades,&#34;  Bryn Talkington  of Requisite Capital Management named  AbbVie Inc. (NYSE: ABBV)
# 2023-03-24T11:30:09Z: UBS Maintains Neutral on Oracle, Raises Price Target to $90
# 2023-03-23T17:20:07Z: TikTok CEO, Asked If Its Chinese Owners Would Divest If Instructed By U.S. Treasury, Says: 'It Is Not About The Ownership'
# 2023-03-23T17:00:45Z: CNBC Halftime Report Final Trades: AbbVie, Nike, Oracle And FedEx
# 2023-03-23T16:47:52Z: Watching Oracle; Josh Brown Says Oracle Will Be The Winner; Best Way To Play TikTok Continuing But With A Divestiture Or Sale; Shares Move Higher
# 2023-03-22T16:46:15Z: Nvidia CEO Proclaims AI's 'iPhone Moment' Has Begun: Analysts Respond – summary: At the GPU Technology Conference on Tuesday, Nvidia Corporation’s (NASDAQ: NVDA) CEO Jensen Huang said that the “iPhone moment for AI” has started.
# 2023-03-21T18:45:54Z: (ORCL) - Analyzing Oracle's Short Interest
#
#
# Analysis by Libra Anker:
# Thank you for your query regarding Oracle Corporation. Here is the information that you requested:
#
# - Forward P/E Ratio: As of March 25th, 2023, Oracle Corporation's forward P/E ratio is 15.38. This indicates that the market expects the company's earnings to grow at a steady rate in the coming years.
#
# - Dividend Yield: Oracle Corporation currently has a dividend yield of 1.33%. The company has a history of paying out dividends to its shareholders, with a steady increase in the annual dividend rate over the last few years.
#
# - Analyst Recommendations: According to data from Bloomberg, as of March 25th, 2023, 34 analysts cover Oracle Corporation. Out of these, 11 recommend a buy, 18 recommend a hold, and 5 recommend a sell. The consensus target price is $90.98, which represents a potential upside of 8.42% from the current market price.
#
# I hope this information is helpful. Let me know if you need anything else.
#
# Montgomery Frostam's portfolio
# Oracle Corp stock owned: 0 ($0.0 value)
# Portfolio cash available: $-14132.49
# Portfolio total value: $100270.14
#
#
# Your previous notes on Oracle Corp:
# 2023-03-25 19:14:15.965172
#  Oracle Corp is a well-established tech company with a strong financial position, evidenced by its steady revenue growth and healthy net income margin. However, its recent stock price performance has been volatile, and its current price may not accurately reflect its true value. Further research is needed to determine a more accurate valuation.
#
#
# ~ response: Analysis: Oracle Corporation is a well-established tech company that has shown steady revenue growth and a healthy net income margin. Despite this, its recent stock price performance has been volatile, and it may be undervalued at its current price. The company's forward P/E ratio suggests that the market expects its earnings to grow at a steady rate in the coming years. In addition, Oracle has a history of paying out dividends to its shareholders, with a steady increase in the annual dividend rate over the last few years. Based on this information, I believe that Oracle's stock is a good value buy at its current price.
#
# Risk level: Medium
#
# Information requests: Please gather more information on any recent developments or news related to Oracle Corporation that may have an impact on its future stock price performance.
#
# Verdict: Buy 200 shares of Oracle Corporation. This will use approximately 3.6% of Montgomery Frostam's portfolio value and maintain a well-diversified portfolio.
# ~
# {'verdict': 'buy', 'amount': 200, 'symbol': 'ORCL'}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ** tokens: 3286
# ~ prompt:
# Company: Goldman Sachs Group Inc.
# Ask price: 0.0
# Bid price: 0.0
# full trading data (Alpaca Market API, get_stock_snapshot):
# {"symbol": "GS", "latest_trade": {"symbol": "GS", "timestamp": "2023-03-24T19:59:56.226679+00:00", "exchange": "V", "price": 312.58, "size": 100.0, "id": 59620107511615, "conditions": [" "], "tape": "A"}, "latest_quote": {"symbol": "GS", "timestamp": "2023-03-24T20:00:00.004392+00:00", "ask_exchange": "V", "ask_price": 0.0, "ask_size": 0.0, "bid_exchange": "V", "bid_price": 0.0, "bid_size": 0.0, "conditions": ["R"], "tape": "A"}, "minute_bar": {"symbol": "GS", "timestamp": "2023-03-24T19:59:00+00:00", "open": 312.1, "high": 312.58, "low": 312.1, "close": 312.58, "volume": 744.0, "trade_count": 19.0, "vwap": 312.298669}}
#
# last annual income statement for Goldman Sachs Group Inc. (Financial Modeling Prep API):
# ...
# Portfolio cash available: $-14132.49
# Portfolio total value: $100270.14
#
#
# Your previous notes on Credit Suisse Group:
# 2023-03-25 19:15:39.833013
#  Credit Suisse Group has been struggling with low profitability and has been reporting negative net income for the past two years. The recent news surrounding the banking industry's stability and Deutsche Bank's troubles have also added to the uncertainty around the stock. Additionally, the lack of ask and bid prices for the stock is concerning.
#
#
# ~ response: Analysis:
# Credit Suisse Group has been facing significant challenges with its profitability in recent years, reporting negative net income for the past two years. The current debt-to-equity ratio of 3.01 indicates the company's more extensive reliance on debt financing than equity. While the recent management changes might bring some positive changes, it is too soon to evaluate their impact on the company's performance.
#
# Risk level:
# High
#
# Information requests:
# 1. Please provide the last four quarters of Credit Suisse Group's income statement.
# 2. Please provide a detailed analysis of Credit Suisse Group's competitors and their financial performance.
# 3. Please provide the current economic outlook and its potential impact on the financial services sector.
#
# Verdict:
# Hold
# ~
# {'verdict': 'hold', 'amount': 0, 'symbol': 'CS'}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# ** tokens: 2104
# ~ prompt:
# Company: Spire Global, Inc.
# Ask price: 0.0
# Bid price: 0.0
# full trading data (Alpaca Market API, get_stock_snapshot):
# {"symbol": "SPIR", "latest_trade": {"symbol": "SPIR", "timestamp": "2023-03-24T19:58:47.208470+00:00", "exchange": "V", "price": 0.6899, "size": 200.0, "id": 59607607306812, "conditions": [" "], "tape": "A"}, "latest_quote": {"symbol": "SPIR", "timestamp": "2023-03-24T20:00:00.007301+00:00", "ask_exchange": "V", "ask_price": 0.0, "ask_size": 0.0, "bid_exchange": "V", "bid_price": 0.0, "bid_size": 0.0, "conditions": ["R"], "tape": "A"}, "minute_bar": {"symbol": "SPIR", "timestamp": "2023-03-24T19:58:00+00:00", "open": 0.6899, "high": 0.6899, "low": 0.6899, "close": 0.6899, "volume": 200.0, "trade_count": 1.0, "vwap": 0.6899}}
#
# last annual income statement for Spire Global, Inc. (Financial Modeling Prep API):
# {}
#
# previous annual income statement for Spire Global, Inc. (Financial Modeling Prep API):
# {}
#
# last 12 months of the Consumer Price Index (Financial Modeling Prep API):
# [{'date': '2023-02-01', 'value': 301.648}, {'date': '2023-01-01', 'value': 300.536}, {'date': '2022-12-01', 'value': 298.99}, {'date': '2022-11-01', 'value': 298.598}, {'date': '2022-10-01', 'value': 297.987}, {'date': '2022-09-01', 'value': 296.539}, {'date': '2022-08-01', 'value': 295.32}, {'date': '2022-07-01', 'value': 294.628}, {'date': '2022-06-01', 'value': 294.728}, {'date': '2022-05-01', 'value': 291.268}, {'date': '2022-04-01', 'value': 288.611}, {'date': '2022-03-01', 'value': 287.472}]
#
# stock price change data for Spire Global, Inc. (Financial Modeling Prep API):
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#
# Recent news (Benzinga news service):
# 2023-03-24T21:01:10Z: Spire Global Receives Continued Listing Standards Notice From NYSE
# 2023-03-16T18:14:03Z: Stocks That Hit 52-Week Lows On Thursday – summary: Thursday&#39;s session saw 337 companies set new 52-week lows.
# 2023-03-15T21:31:31Z: 12 Industrials Stocks Moving In Wednesday's After-Market Session
# 2023-03-13T13:06:12Z: 8 Industrials Stocks Moving In Monday's Pre-Market Session
# 2023-03-10T13:06:31Z: 12 Industrials Stocks Moving In Friday's Pre-Market Session
# 2023-03-09T14:51:50Z: Benchmark Maintains Buy on Spire Global, Lowers Price Target to $1.24
# 2023-03-09T12:10:33Z: Raymond James Maintains Outperform on Spire Global, Lowers Price Target to $3.5
# 2023-03-08T21:31:09Z: 12 Industrials Stocks Moving In Wednesday's After-Market Session
# 2023-03-08T21:08:13Z: Spire Globall Q4 EPS $(0.10) Misses $(0.09) Estimate, Sales $22.39M Miss $23.36M Estimate
# 2023-03-08T13:06:15Z: 12 Industrials Stocks Moving In Wednesday's Pre-Market Session
#
#
# Analysis by Libra Anker:
# Thank you for your query regarding the ticker symbol SPIR.
#
# After conducting research, I found that SPIR, or Spire Global Inc, is a space-to-cloud analytics company that specializes in tracking and predictive analytics for weather, maritime, and aviation industries.
#
# In terms of recent initiatives to improve its financial performance, SPIR has announced the completion of its merger with NavSight Holdings Inc, a publicly traded special purpose acquisition company (SPAC). This merger has allowed SPIR to become a publicly traded company and has given it access to additional capital to fuel its expansion plans.
#
# Regarding updates on its contracts with customers in the aviation industry, SPIR has recently announced a partnership with JetBlue Airways to provide real-time data and analytics for air traffic management. Additionally, SPIR has secured a contract with the Federal Aviation Administration (FAA) to provide space-based Automatic Dependent Surveillance-Broadcast (ADS-B) data to improve air traffic management across the United States.
#
# I hope this information helps in your decision-making process. Please let me know if you need any further information or clarification.
#
# Montgomery Frostam's portfolio
# Spire Global, Inc. stock owned: 0 ($0.0 value)
# Portfolio cash available: $-14132.49
# Portfolio total value: $100270.14
#
#
# Your previous notes on Spire Global, Inc.:
# 2023-03-25 19:15:50.283035
#  Spire Global, Inc. is a satellite-powered data company providing services to customers in the aviation, weather, shipping, and space industries. The company has been experiencing losses, reporting a net loss of $89.4 million in its latest annual income statement. Its last reported revenue for the year 2022 was $80.3 million, which is an increase from the previous year but still on the lower side. Additionally, there have been recent news reports about the company receiving a continued listing standards notice from NYSE and missing earnings estimates. Overall, the company's fundamentals do not seem to indicate a strong potential for growth at the moment.
#
#
# ~ response: Analysis:
# Spire Global, Inc. is a company with a focus on space-to-cloud analytics, which includes weather, maritime, and aviation industries. The company has recently completed a merger with NavSight Holdings Inc, making it a publicly traded company and providing additional funding for expansion. However, the company has been experiencing losses, reporting a net loss of $89.4 million in its latest annual income statement. There have also been recent news reports about the company receiving a continued listing standards notice from NYSE and missing earnings estimates.
#
# Risk level: high
#
# Information requests:
# 1. What is the current state of the aviation industry, and how might this affect Spire Global's partnership with JetBlue Airways and contract with the FAA?
# 2. What is the potential impact of the continued listing standards notice from NYSE on the company's stock price and future prospects?
#
# Verdict: pass. At this time, due to the company's financial performance and recent news reports, I recommend that Mr. Frostam hold off on investing in Spire Global, Inc.
# ~
# {'verdict': 'pass', 'amount': 0, 'symbol': 'SPIR'}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# no oracle request FRC
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# no oracle request TSLA
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# no oracle request ARKK
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# no oracle request BGRY
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# no oracle request SPY
# FFNTF snapshot not found
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# no oracle request AMAT
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# ** tokens: 1869
# ~ prompt:
# Company: Cybin Inc.
# Ask price: 0.0
# Bid price: 0.0
# full trading data (Alpaca Market API, get_stock_snapshot):
# {"symbol": "CYBN", "latest_trade": {"symbol": "CYBN", "timestamp": "2023-03-24T19:32:01.909668+00:00", "exchange": "V", "price": 0.3822, "size": 100.0, "id": 58692260881260, "conditions": [" "], "tape": "B"}, "latest_quote": {"symbol": "CYBN", "timestamp": "2023-03-24T20:00:00.007524+00:00", "ask_exchange": "V", "ask_price": 0.0, "ask_size": 0.0, "bid_exchange": "V", "bid_price": 0.0, "bid_size": 0.0, "conditions": ["R"], "tape": "B"}, "minute_bar": {"symbol": "CYBN", "timestamp": "2023-03-24T19:32:00+00:00", "open": 0.3822, "high": 0.3822, "low": 0.3822, "close": 0.3822, "volume": 100.0, "trade_count": 1.0, "vwap": 0.3822}}
#
# last annual income statement for Cybin Inc. (Financial Modeling Prep API):
# {}
#
# previous annual income statement for Cybin Inc. (Financial Modeling Prep API):
# {}
#
# last 12 months of the Consumer Price Index (Financial Modeling Prep API):
# [{'date': '2023-02-01', 'value': 301.648}, {'date': '2023-01-01', 'value': 300.536}, {'date': '2022-12-01', 'value': 298.99}, {'date': '2022-11-01', 'value': 298.598}, {'date': '2022-10-01', 'value': 297.987}, {'date': '2022-09-01', 'value': 296.539}, {'date': '2022-08-01', 'value': 295.32}, {'date': '2022-07-01', 'value': 294.628}, {'date': '2022-06-01', 'value': 294.728}, {'date': '2022-05-01', 'value': 291.268}, {'date': '2022-04-01', 'value': 288.611}, {'date': '2022-03-01', 'value': 287.472}]
#
# stock price change data for Cybin Inc. (Financial Modeling Prep API):
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
#
# Recent news (Benzinga news service):
# 2023-03-24T21:30:06Z: GH Research, Cybin Among Top Psychedelic Movers Of Today
# 2023-03-23T21:30:06Z: GH Research, Compass Pathways Among Top Psychedelic Movers Of Today
# 2023-03-22T21:30:06Z: Psychedelic Stock Gainers And Losers From March 22, 2023
# 2023-03-21T21:30:05Z: Psychedelic Stock Gainers And Losers From March 21, 2023
# 2023-03-20T21:30:06Z: Psychedelic Stock Gainers And Losers From March 20, 2023
# 2023-03-17T21:30:06Z: Psychedelic Stock Gainers And Losers From March 17, 2023
# 2023-03-16T21:30:05Z: Seelos Therapeutics, Compass Pathways Among Top Psychedelic Movers Of Today
# 2023-03-15T21:30:06Z: Seelos Therapeutics, Cybin Among Top Psychedelic Movers Of Today
# 2023-03-14T21:30:06Z: Seelos Therapeutics, ATAI Life Sciences Among Top Psychedelic Movers Of Today
# 2023-03-13T21:30:06Z: ATAI Life Sciences, Compass Pathways Among Top Psychedelic Movers Of Today

# %% [markdown]
# Hahaha. Libra just makes up a $114 million quarterly profit. Yikes. And somehow today the quarterly earnings data is no longer available (maybe I was on a trial for those particular endpoints? Boo)

# %% [markdown]
# ## Making Libra better

# %% [markdown]
# I was surprised to see that the oracle, Libra Anker, knew about Silicon Valley Bank collapsing. Looks like it only knew about it because the question mentioned it. I know that LLMs are supposed to be excellent bullshit machines, but when they have correct information they can get much closer to the truth. Right now, though, Libra Anker is a more pure bullshit machine. Let me do a quick analysis to see what information I could pass in her prompt so she could bullshit less. And in general:
# - pass data to Libra to maximize the number of questions she'll have information on
# - come up with other "advisor" figures who can chime in on certain dimensional axes. How about an advisor for each major industry? For popular sentiment? Etc
# - Maybe I could make an advisor that could just query FMP...

# %%
from datetime import datetime
queries = defaultdict(list)
for symbol, note_list in notes.items():
    # note = note_list[-1]
    # print(symbol, extract_query(note['note']))
    for note in note_list:
        query = extract_query(note['note'])
        queries[symbol].append({ 'symbol': symbol, 'query': query, 'date_str': note['date'] })

# %%
q_str = ''
for symbol, qlist in queries.items():
    # print(symbol)
    for q in qlist:
        # print('\t-'+q['query'])
        q_str += '-'+q['query'].replace('\n', ' ') + '\n'

# %%
print(q_str)
# Out:
# -Please gather further data on NVDA's dividend history, market competition, and supply chain risks.
# -Please gather further data on NVDA's dividend history, market competition, and supply chain risks.
# -Please gather further data on NVDA's dividend history, market competition, and supply chain risks.
# -Please provide the latest quarterly report for NVDA and any news on upcoming product launches.
# -Please check the latest news on General Mills, Inc. and any upcoming changes.
# -1. Latest earnings call notes  2. Competitors' sales growth figures  3. Dividend history and payout ratio
# -"latest news on Monster Beverage Corporation"
# -Please provide the latest updates on the company's marketing strategies and product innovations. Also, provide an overview of the competition in the consumer goods industry, with a focus on the companies that directly compete with Procter & Gamble.
# -Please provide a detailed analysis of AIG's recent business performance and future growth prospects. Also, provide the latest update on the interest rate environment and inflation trends.
# -1. The recent initiatives taken by the company to boost profitability. 2. The industry and market trends with respect to hospitality companies.
# -Search for recent news surrounding Yum! Brands, Inc. to get an idea of the future outlook for the company. Additionally, look into the company's competition and industry trends.
# -Search for news articles and analyst reports on Exelon Corporation's current operations, any major upcoming projects, and their expected impact on the company's stock price. Additionally, retrieve historical trends and the future outlook of the utility sector.
# -Search for recent news about Kimberly-Clark Corp.'s management and plans for future growth.
# -1. American Water Works Company, Inc's 5-year financial analysis.  2. A comparison of American Water Works Company, Inc's financial ratios with those of its peers.
# -"Merck & Co., Inc. share price forecast for the next year", "Recent developments in Merck & Co.'s oncology pipeline", "Competitors' stock prices and market share in the pharmaceutical industry"
# -1) Recent news (if available) 2) Dividend history of Ecolab, Inc. 3) Industry comparison of valuation ratios
# -Please provide news search results for Wabtec Inc. over the past month.
# -Please gather news on the reasons behind the recent decline in the stock price of PNC Financial Services Group.
# -Please retrieve current industry trends on health insurance companies, and the recent impacts of inflation on the healthcare industry.
# -Please search for recent news on Intel's restructuring plan and any updates on chip demand and supply chain issues.
# -1. Please provide the last four quarters of Credit Suisse Group's income statement. 2. Please provide a detailed analysis of Credit Suisse Group's competitors and their financial performance. 3. Please provide the current economic outlook and its potential impact on the financial services sector.
# -Please gather data on the company's recent initiatives to improve its financial performance, and any updates on its contracts with customers in the aviation industry.
# -1. What is the current state of the aviation industry, and how might this affect Spire Global's partnership with JetBlue Airways and contract with the FAA? 2. What is the potential impact of the continued listing standards notice from NYSE on the company's stock price and future prospects?
# -Please provide more information on Seelos Therapeutics' current clinical trials and any updates on the progress of its drug candidates.
# -Please provide information on the competitors of Seelos Therapeutics and any recent news about ASIB or MDD treatments.
# -Please gather information about Goldman Sachs Group Inc.'s current debt load and any recent changes to their leadership team.
# -1. Can you provide an analysis of the company's debt and how it might impact their financial stability? 2. Can you research any recent news or analyst reports that might explain the recent downward trend in the company's financial performance?
# -1. What is the status of the takeover bids?  2. What is the projected 5-year growth rate of the professional football league?  3. What is the outlook for Manchester United's performance in the upcoming season?
# -Please get the latest news on the takeover bids from Sheikh Jassim Bin Hamad Al Thani and Jim Ratcliffe and whether any new bids have been made by other investors.
# -Please provide the latest annual income statement and any other financial data available for ARK Fintech Innovation ETF.
# -Please provide any additional financial data available for ARK Fintech Innovation ETF, including the fund's performance history and any relevant news on its holdings.
# -Please gather more data on Lucid Group, Inc.'s competition in the electric vehicle market, their production capacity, and updates on their financial situation.
# -Please provide more information on Lucid Group, Inc.'s progress towards increasing its production capacity to 85,000 units per year by 2026.

# %%
response = query_openai('''The following is a list of queries for a researcher. Please re-order the list by type of request.

'''+q_str, '')

# %%
print(response)
# Out:
# Financial Data:
# - Dividend history and payout ratio for NVDA
# - Latest quarterly report for NVDA
# - AIG's recent business performance and future growth prospects
# - P/E ratio, dividend yield, and cash flow analysis of ExxonMobil Corporation
# - Latest annual report for Phillips 66 and Phillips 66 competitors in the energy and petrochemical industries
# - Current P/E ratio, P/B ratio, and dividend yield of Evergy, Inc.
# - Cincinnati Financial Corporation Common Stock SWOT analysis
# - Comerica Incorporated market trends and competitor analysis
# - Latest quarterly report and Consumer Price Index data
# - Credit Suisse Group's debt-to-equity ratio and any recent changes in management
# - Goldman Sachs Group Inc.'s current debt load and any recent changes to their leadership team
# - Latest annual income statement and any other financial data available for ARK Fintech Innovation ETF
#
# News and Updates:
# - Latest news on Monster Beverage Corporation
# - Latest updates on NVDA's dividend history, market competition, and supply chain risks
# - Recent developments in Merck & Co.'s oncology pipeline, competitors' stock prices, and market share in the pharmaceutical industry
# - Latest news on General Mills, Inc. and any upcoming changes
# - News search results for Wabtec Inc. over the past month
# - Recent news articles about any changes in company leadership or any major partnerships or collaborations that they might have announced
# - Latest news on Apple's product launches, legal and regulatory issues, and potential concerns about supply chain disruptions or production delays
# - News and analysis on recent events that could potentially impact senior housing, medical office, and skilled nursing facilities, and insights on other companies in the REIT industry similar to Welltower Inc.
# - Latest news on Marsh & McLennan Companies, Inc. in the past month, analyst recommendations for MMC stock, and trends in the insurance industry
# - Recent news about JPMorgan Chase & Co., including current P/E ratio of JPM's stock, and research on recent trends in interest rates and inflation
# - Latest news on Constellation Brands, Inc. and any major competitors in the industry
# - Updates on the company's marketing strategies and product innovations, as well as an overview of the competition in the consumer goods industry, with a focus on the companies that directly compete with Procter & Gamble
# - Recent news about Kimberly-Clark Corp.'s management and plans for future growth
# - Latest news on DXC's

# %% [markdown]
# Notes
# - cash flow statement is already in annual report
# - including quarterly report would be great though
# - PE ratio for industry: https://financialmodelingprep.com/api/v4/industry_price_earning_ratio?date=2021-05-07&exchange=NYSE&apikey=db39ae5b594e7fde421d83fdde927c21

# %% [markdown]
# Could try something like this prompt for API access, might sometimes work:
#
# ```
# The following is a high-level description of a financial information API. Please construct a correct URL to query the data necessary to answer questions.
# For example, to get Microsoft's latest quarterly report, you would return: /api/v4/financial-reports-json?symbol=MSFT&year=2023&period=Q1&apikey=YOUR_API_KEY
#
# This is the following question to query data for:
# "What is the current state of the aviation industry"
#
# Today is March 25, 2023.
#
# --------------------------
#
#
# ## Company Financial Statements
# Your API Key : 7648d7883571b6f3daeb64b1a307f29a
#
# Income Statement
# Annual income statements Annual JSON: /api/v3/income-statement/AAPL?limit=120&apikey=YOUR_API_KEY
# Quarterly income statements Quarter JSON: /api/v3/income-statement/AAPL?period=quarter&limit=400&apikey=YOUR_API_KEY
# Income statements by CIK JSON: /api/v3/income-statement/0001318605?period=quarter&apikey=YOUR_API_KEY
#
# Balance Sheet Statement
# Annual balance sheet statements Annual JSON: /api/v3/balance-sheet-statement/AAPL?limit=120&apikey=YOUR_API_KEY
# Quarterly balance sheet statements Quarter JSON: /api/v3/balance-sheet-statement/AAPL?period=quarter&limit=400&apikey=YOUR_API_KEY
# Balance sheet statements by CIK JSON: /api/v3/balance-sheet-statement/0001318605?period=quarter&apikey=YOUR_API_KEY
#
# Cash Flow Statement
# Annual cash flow statements Annual JSON: /api/v3/cash-flow-statement/AAPL?limit=120&apikey=YOUR_API_KEY
# Quarterly cash flow statements Quarter JSON: /api/v3/cash-flow-statement/AAPL?period=quarter&limit=400&apikey=YOUR_API_KEY
# Cash Flow statements by CIK JSON: /api/v3/cash-flow-statement/0001318605?period=quarter&apikey=YOUR_API_KEY
#
# Quarterly Earnings Reports
# Quarterly Earnings Reports. Period accepted: Q1/Q2/Q3/Q4 JSON: /api/v4/financial-reports-json?symbol=AAPL&year=2020&period=Q1&apikey=YOUR_API_KEY
#
# Sectors PE Ratio
# Average price to earnings ratio for sectors: /api/v4/sector_price_earning_ratio?date=2021-05-07&exchange=NYSE&apikey=YOUR_API_KEY
#
# Industries PE Ratio
# Average price to earnings ratio for industries JSON: /api/v4/industry_price_earning_ratio?date=2021-05-07&exchange=NYSE&apikey=YOUR_API_KEY
#
# Stock Market Sectors Performance
# Stock Market Sectors Performance. Hourly JSON: /api/v3/sector-performance?apikey=YOUR_API_KEY
# Historical sector performance. JSON: /api/v3/historical-sectors-performance?limit=50&apikey=YOUR_API_KEY
# ```
#
# This did return a working endpoint calling sector-performance, but querying in a follow-up prompt asking it if the data could answer the question led to it saying it could not (and I agree).

# %% [markdown]
# For the q: "Please provide information on Credit Suisse Group's debt-to-equity ratio and any recent changes in its management." using the above prompt templates returns this endpoint:
#
# `api/v3/balance-sheet-statement/0001318605?period=quarter&apikey=7648d7883571b6f3daeb64b1a307f29a`
#
# Not sure if that number refers to Credit Suisse, but I wouldn't think so. Endpoint just tells me I've run out of their limit for the day and I should start paying for the API. But using their sample data for that endpoint and feeding it back to GPT after switching out the symbols:
#
# `Based on the data provided, Credit Suisse Group's debt-to-equity ratio is 0.19 as of September 25, 2021. The total debt is 124719000000 USD and the total equity is 63090000000 USD. There has been no recent changes in management.`
#
# The date is correct, and the numbers it pulled are correct. The calculation is just wrong. And it's actually data for Apple, but that's just a problem with the data. I asked it to write some Python code if it needed to do a calculation, but it didn't. Maybe GPT4 will be more reliable. The calculation is so wrong that I'd hesitate to crap like this in the main prompt I'm passing to Fantasia.

# %% [markdown]
# I'll try another query for information, trying again to find one that has a chance of working... this one should be easy, no?
#
# "Please provide the latest annual income statement and any other financial data available for ARK Fintech Innovation ETF."
#
# It returned: `Answer: /api/v3/income-statement/ARKF?limit=120&apikey=7648d7883571b6f3daeb64b1a307f29a`. It seems to like the Answer: format, so I'm incorporating that into the prompt so I'll be able to string match to it.
#
# Interestingly the endpoint returns nothing, but assuming it would work if my API key worked, I feed it in the Apple dummy data and get:
#
# `Based on the data provided, ARK Fintech Innovation ETF had an annual revenue of $36.58 billion, cost of revenue of $21.30 billion, gross profit of $15.28 billion, operating expenses of $4.39 billion, cost and expenses of $25.69 billion, interest income of $2.84 billion, interest expense of $2.64 billion, depreciation and amortization of $11.28 billion, operating income of $10.89 billion, income before taxes of $10.92 billion, income tax expense of $1.45 billion, and net income of $9.47 billion in 2021. The earnings per share (EPS) was $5.46.`
#
# Hmm... the actual data it pulled is:
# ```
#     "revenue" : 365817000000,
#     "costOfRevenue" : 212981000000,
#     "costAndExpenses" : 256868000000,
#     "operatingExpenses" : 43887000000,
# ...
# ```
#
# If those units are dollars, it's 365 B, not 36. Since it's Apple, they probably did do that much revenue, jesus. (Confirmed)
# GPT-4 gets the correct order of magnitude:
#
# ```
# The latest annual income statement available for ARK Fintech Innovation ETF (ARKF) is for the fiscal year ending on September 25, 2021. Here are the key figures from the income statement:
#
# - Revenue: $365,817,000,000
# - Cost of Revenue: $212,981,000,000
# ...
# ```

# %% [markdown]
# ## why isn't the quarterly endpoint working anymore?

# %%
with open('fundamentals-keys.json') as f:
    fmp_key = json.loads(f.read())['fmp_key']
def get_quarterly(symbol, idx=0):
    fmp_base_url_v3 = "https://financialmodelingprep.com/api/v3"
    j = requests.get(f"{fmp_base_url_v3}/income-statement/{symbol}?period=quarter&limit={idx+1}&apikey={fmp_key}").json()
    try:
        return j[idx]
    except:
        print(j)
        return {}

# %%
get_quarterly('AAPL')
# Out:
# {'Error Message': 'Limit Reach . Please upgrade your plan or visit our documentation for more details at https://site.financialmodelingprep.com/'}
# {}

# %% [markdown]
# Okay, so I can't do quarterly period. Although it worked yesterday :shrug:
